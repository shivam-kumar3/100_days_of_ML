# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("https://gist.githubusercontent.com/tijptjik/9408623/raw/b237fa5848349a14a14e5d4107dc7897c21951f5/wine.csv" , usecols=[0,1,2])

# %%
df
# Out:
#      Class_label  Alcohol  Malic_acid
# 0              1    14.23        1.71
# 1              1    13.20        1.78
# 2              1    13.16        2.36
# 3              1    14.37        1.95
# 4              1    13.24        2.59
# ..           ...      ...         ...
# 173            3    13.71        5.65
# 174            3    13.40        3.91
# 175            3    13.27        4.28
# 176            3    13.17        2.59
# 177            3    14.13        4.10
#
# [178 rows x 3 columns]

# %%
sns.kdeplot(df["Alcohol"])
# Out:
# <Axes: xlabel='Alcohol', ylabel='Density'>

# %%
sns.kdeplot(df["Malic_acid"])
# Out:
# <Axes: xlabel='Malic_acid', ylabel='Density'>

# %%
colors = {1:"red",2:"blue",3:"green"}
sns.scatterplot(data=df,x="Alcohol",y="Malic_acid",hue = "Class_label",palette = colors)
# Out:
# <Axes: xlabel='Alcohol', ylabel='Malic_acid'>

# %%
from sklearn.model_selection import train_test_split

# %%
x= df.drop("Class_label", axis = 1)
y= df["Class_label"]

# %%
x_train,x_test,y_train,y_test = train_test_split (x,y,test_size = 0.3,random_state=0)

# %%
x_train.shape,x_test.shape
# Out:
# ((124, 2), (54, 2))

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(x_train)
# Out:
# MinMaxScaler()

# %%
x_train_scaled = scaler.transform(x_train)
X_test_scaled = scaler.transform(x_test)

# %%
x_train_scaled = pd.DataFrame(x_train_scaled, columns = x_train.columns)
x_test_scaled = pd.DataFrame(x_train_scaled, columns = x_test.columns)

# %%
x_train_scaled
# Out:
#       Alcohol  Malic_acid
# 0    0.720430    0.203782
# 1    0.319892    0.084034
# 2    0.602151    0.712185
# 3    0.572581    0.563025
# 4    0.760753    0.130252
# ..        ...         ...
# 119  0.212366    0.174370
# 120  0.360215    0.058824
# 121  0.373656    0.151261
# 122  0.771505    0.165966
# 123  0.841398    0.340336
#
# [124 rows x 2 columns]

# %%
np.round(x_train.describe(),2)
# Out:
#        Alcohol  Malic_acid
# count   124.00      124.00
# mean     12.98        2.38
# std       0.80        1.14
# min      11.03        0.89
# 25%      12.36        1.61
# 50%      13.04        1.88
# 75%      13.64        3.25
# max      14.75        5.65

# %%
np.round(x_train.describe(),2)
# Out:
#        Alcohol  Malic_acid
# count   124.00      124.00
# mean     12.98        2.38
# std       0.80        1.14
# min      11.03        0.89
# 25%      12.36        1.61
# 50%      13.04        1.88
# 75%      13.64        3.25
# max      14.75        5.65

# %%
np.round(x_train_scaled.describe(),2)
# Out:
#        Alcohol  Malic_acid
# count   124.00      124.00
# mean      0.53        0.31
# std       0.22        0.24
# min       0.00        0.00
# 25%       0.36        0.15
# 50%       0.54        0.21
# 75%       0.70        0.50
# max       1.00        1.00

# %%
fig,(a,b) = plt.subplots(ncols = 2, figsize =(10,5))
a.scatter(x_train["Alcohol"],x_train["Malic_acid"],c="red")
a.set_title("Before Normalization")

b.scatter(x_train_scaled["Alcohol"], x_train_scaled["Malic_acid"], c="blue")
b.set_title("After Normalization")
# Out:
# Text(0.5, 1.0, 'After Normalization')

# %%
fig, (a,b) = plt.subplots(ncols = 2,figsize = (12,5))
#BEFORE SCALING (NORMALIZATION)
sns.kdeplot(x_train["Alcohol"],ax=a)
sns.kdeplot(x_train["Malic_acid"],ax=a)

#AFTER SCALLING (NORMALIZATION)
sns.kdeplot(x_train_scaled["Alcohol"], ax=b)
sns.kdeplot(x_train_scaled["Malic_acid"],ax=b)
# Out:
# <Axes: xlabel='Alcohol', ylabel='Density'>

# %%
fig, (a,b) = plt.subplots(ncols = 2,figsize = (12,5))
#BEFORE SCALING (NORMALIZATION)
sns.kdeplot(x_train["Alcohol"],ax=a)
a.set_title("Alcohol Distribution before scaling")

#AFTER SCALLING (NORMALIZATION)
sns.kdeplot(x_train_scaled["Alcohol"], ax=b)
b.set_title("Alcohol Distribution after scaling")
# Out:
# Text(0.5, 1.0, 'Alcohol Distribution after scaling')

# %%
fig, (a,b) = plt.subplots(ncols = 2,figsize = (12,5))
#BEFORE SCALING (NORMALIZATION)
a.set_title = ("Malic Acid Distribution before scaling")
sns.kdeplot(x_train["Malic_acid"],ax=a)

#AFTER SCALLING (NORMALIZATION)

sns.kdeplot(x_train_scaled["Malic_acid"],ax=b)
b.set_title = ("Malic Acid Distribution after scaling")

# %%
|
