# %% [markdown]
# IMPORTING PANDAS

# %%
import pandas as pd

# %% [markdown]
# opening a local csv file

# %%
df = pd.read_csv("PLACEMENT.csv")

# %%
df.head()
# Out:
#    CPGA  IQ  PLACEMENT
# 0     3  56          0
# 1     3  94          1
# 2    10  67          0
# 3     4  50          0
# 4     9  92          1

# %% [markdown]
# OPENING A CSV FILE FROM AN URL

# %%
import requests
from io import StringIO
url = "https://raw.githubusercontent.com/codeforamerica/ohana-api/master/data/sample-csv/addresses.csv"

headers=  {"User-Agent": "Mozilla/5.0 (Macintosh;Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}

req = requests.get(url, headers=headers)

data = StringIO(req.text)

pd.read_csv(data)
# Out:
#     id  location_id                   address_1  address_2  \
# 0    1            1       2600 Middlefield Road        NaN
# 1    2            2            24 Second Avenue        NaN
# 2    3            3            24 Second Avenue        NaN
# 3    4            4            24 Second Avenue        NaN
# 4    5            5            24 Second Avenue        NaN
# 5    6            6           800 Middle Avenue        NaN
# 6    7            7              500 Arbor Road        NaN
# 7    8            8           800 Middle Avenue        NaN
# 8    9            9       2510 Middlefield Road        NaN
# 9   10           10       1044 Middlefield Road        NaN
# 10  11           11         2140 Euclid Avenue.        NaN
# 11  12           12       1044 Middlefield Road  2nd Floor
# 12  13           13         399 Marine Parkway.        NaN
# 13  14           14          660 Veterans Blvd.        NaN
# 14  15           15        1500 Valencia Street        NaN
# ...

# %% [markdown]
# SEP PARAMETER

# %%
tab = pd.read_csv("sample-1.tsv", sep ="\t")

# %%
tab
# Out:
#     Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0          NaN    JANUARY        NaN        NaN        NaN        NaN
# 1          NaN          S          M          T          W          T
# 2          NaN        NaN        NaN        NaN        NaN        NaN
# 3          NaN          2          3          4          5          6
# 4          NaN          9         10         11         12         13
# 5          NaN         16         17         18         19         20
# 6          NaN         23         24         25         26         27
# 7          NaN         30         31        NaN        NaN        NaN
# 8          NaN        NaN        NaN        NaN        NaN        NaN
# 9          NaN     APRIL         NaN        NaN        NaN        NaN
# 10         NaN          S          M          T          W          T
# 11         NaN        NaN        NaN        NaN        NaN        NaN
# ...

# %% [markdown]
# INDEX PARAMETER

# %%
bus = pd.read_csv("business.csv", index_col = "Series_reference")

# %%
bus.head()
# Out:
#                    Period  Data_value Suppressed STATUS   UNITS  Magnitude  \
# Series_reference
# BDCQ.SEA1AA       2011.06     80078.0        NaN      F  Number          0
# BDCQ.SEA1AA       2011.09     78324.0        NaN      F  Number          0
# BDCQ.SEA1AA       2011.12     85850.0        NaN      F  Number          0
# BDCQ.SEA1AA       2012.03     90743.0        NaN      F  Number          0
# BDCQ.SEA1AA       2012.06     81780.0        NaN      F  Number          0
#
#                                          Subject  \
# Series_reference
# BDCQ.SEA1AA       Business Data Collection - BDC
# BDCQ.SEA1AA       Business Data Collection - BDC
# BDCQ.SEA1AA       Business Data Collection - BDC
# BDCQ.SEA1AA       Business Data Collection - BDC
# BDCQ.SEA1AA       Business Data Collection - BDC
#
#                                             Group Series_title_1  \
# Series_reference
# BDCQ.SEA1AA       Industry by employment variable    Filled jobs
# ...

# %% [markdown]
# HEADER PARAMETER

# %%
bus2 = pd.read_csv("BUSINESS2.csv",header = 0)

# %%
bus2
# Out:
#          BDCQ.SEA1AA  Series_reference   Period Data_value Suppressed  STATUS  \
# 0        BDCQ.SEA1AA           2011.06  80078.0        NaN          F  Number
# 1        BDCQ.SEA1AA           2011.09  78324.0        NaN          F  Number
# 2        BDCQ.SEA1AA           2011.12  85850.0        NaN          F  Number
# 3        BDCQ.SEA1AA           2012.03  90743.0        NaN          F  Number
# 4        BDCQ.SEA1AA           2012.06  81780.0        NaN          F  Number
# ...              ...               ...      ...        ...        ...     ...
# 22571  BDCQ.SEE3999A           2017.06      NaN          Y          C  Number
# 22572  BDCQ.SEE3999A           2017.09      NaN          Y          C  Number
# 22573  BDCQ.SEE3999A           2017.12      NaN          Y          C  Number
# 22574  BDCQ.SEE3999A           2018.03      NaN          Y          C  Number
# 22575  BDCQ.SEE3999A           2018.06      NaN          Y          C  Number
#
# ...

# %% [markdown]
# use_col parameter

# %%
bus = pd.read_csv("business.csv", usecols = ["Data_value","UNITS"])

# %%
bus.head()
# Out:
#    Data_value   UNITS
# 0     80078.0  Number
# 1     78324.0  Number
# 2     85850.0  Number
# 3     90743.0  Number
# 4     81780.0  Number

# %% [markdown]
# skiprows/nrows parameter

# %%
bus = pd.read_csv("business.csv", skiprows  = [0,5])

# %%
bus.head()
# Out:
#    BDCQ.SEA1AA  2011.06    80078 Unnamed: 3  F  Number  0  \
# 0  BDCQ.SEA1AA  2011.09  78324.0        NaN  F  Number  0
# 1  BDCQ.SEA1AA  2011.12  85850.0        NaN  F  Number  0
# 2  BDCQ.SEA1AA  2012.03  90743.0        NaN  F  Number  0
# 3  BDCQ.SEA1AA  2012.09  79261.0        NaN  F  Number  0
# 4  BDCQ.SEA1AA  2012.12  87793.0        NaN  F  Number  0
#
#    Business Data Collection - BDC  Industry by employment variable  \
# 0  Business Data Collection - BDC  Industry by employment variable
# 1  Business Data Collection - BDC  Industry by employment variable
# 2  Business Data Collection - BDC  Industry by employment variable
# 3  Business Data Collection - BDC  Industry by employment variable
# 4  Business Data Collection - BDC  Industry by employment variable
#
#    Filled jobs  Agriculture, Forestry and Fishing  Actual  Unnamed: 12  \
# 0  Filled jobs  Agriculture, Forestry and Fishing  Actual          NaN
# ...

# %%
bus = pd.read_csv("business.csv", nrows = 100)

# %%
bus
# Out:
#    Series_reference   Period  Data_value  Suppressed STATUS   UNITS  \
# 0       BDCQ.SEA1AA  2011.06       80078         NaN      F  Number
# 1       BDCQ.SEA1AA  2011.09       78324         NaN      F  Number
# 2       BDCQ.SEA1AA  2011.12       85850         NaN      F  Number
# 3       BDCQ.SEA1AA  2012.03       90743         NaN      F  Number
# 4       BDCQ.SEA1AA  2012.06       81780         NaN      F  Number
# ..              ...      ...         ...         ...    ...     ...
# 95      BDCQ.SEA1AS  2022.06       98218         NaN      R  Number
# 96      BDCQ.SEA1AS  2022.09       96741         NaN      R  Number
# 97      BDCQ.SEA1AS  2022.12       95119         NaN      R  Number
# 98      BDCQ.SEA1AS  2023.03       95161         NaN      R  Number
# 99      BDCQ.SEA1AS  2023.06       95635         NaN      R  Number
#
#     Magnitude                         Subject  \
# 0           0  Business Data Collection - BDC
# 1           0  Business Data Collection - BDC
# ...

# %% [markdown]
# ENCODING PARAMETERM

# %%
zom = pd.read_csv('zomato.csv', encoding = "latin-1")

# %%
zom.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...
